# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
path=os.getcwd()+'/Big_mart.csv'
df=pd.read_csv(path)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df=df.fillna(df.mean())
df['Item_Visibility'].replace(0.000000,df['Item_Visibility'].mean(),inplace=True)
df['Outlet_Size']=df['Outlet_Size'].fillna((df['Outlet_Size'].mode()[0]))
df['Item_Fat_Content'].replace(['LF','low fat'],'Low Fat',inplace=True)
df['Item_Fat_Content'].replace('reg','Regular',inplace=True)

# %%
sns.kdeplot(df['Item_Weight'])

# %%
sns.kdeplot(df['Item_Outlet_Sales'])

# %%
sns.kdeplot(df['Item_MRP'])

# %%
sns.kdeplot(df['Item_Visibility'])

# %%
c=df.corr()
sns.heatmap(c)

# %%
plt.scatter(df['Item_Visibility'], df['Item_Outlet_Sales'],color='g')

# %%
plt.figure(figsize=(18,8))
sns.boxplot(x='Outlet_Identifier',y='Item_Outlet_Sales',data=df)

# %%
sns.jointplot(x='Item_MRP',y='Item_Outlet_Sales',data=df,color='b')

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='Item_Type',y='Item_Outlet_Sales',data=df)

# %%
sns.lmplot(x='Item_MRP',y='Item_Outlet_Sales',data=df,hue='Outlet_Identifier',fit_reg=False)
